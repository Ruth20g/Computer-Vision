# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
#Load the image
image= cv2.imread("images/lenna.png",0)

# %%
# Sobel parameters: ksize, dx, dy, depth
sobelx= cv2.Sobel(image, cv2.CV_64F,1,0,ksize=3) #sobel for horizontal edges
sobely= cv2.Sobel(image, cv2.CV_64F,0,1,ksize=3) #sobel for vertical edges

#combine the Sobel images(optional)
combined_sobel= cv2.add(sobelx, sobely)

# %%
thresh, binary_sobel= cv2.threshold(combined_sobel, 60, 255,cv2.THRESH_BINARY)

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,4,1)
plt.title('Original Image')
plt.imshow(image, cmap='gray')
plt.subplot(1,4,2) ; plt.title('Sobel X')
plt.imshow(sobelx, cmap='gray')
plt.subplot(1,4,3)
plt.title(' Sobel Y')
plt.imshow(sobely, cmap='gray')
plt.subplot(1,4,4)
plt.title('Final')
plt.imshow(binary_sobel, cmap='gray')

# %%
combined_sobel.astype(np.uint)
# Out:
# array([[   0.,   -4.,   -8., ...,  -64., -148.,    0.],
#        [   0.,   -4.,   -8., ...,  -64., -148.,    0.],
#        [   0.,   -4.,   -8., ...,  -64., -148.,    0.],
#        ...,
#        [ -12.,   22.,   32., ...,   14.,   32.,   44.],
#        [   0.,   44.,   42., ...,   18.,   36.,   28.],
#        [   0.,   44.,   32., ...,   12.,   20.,    0.]])

# %%
img1= cv2.imread('images/lenna.png')
img2= cv2.imread('images/sun.png')

# %%
img1.shape
# Out:
# (512, 512, 3)

# %%
img2.shape
# Out:
# (512, 512, 3)

# %%
new_img= cv2.add(img1,img2)
final_img= np.hstack([img1,img2,new_img]) #horizontal stacking

# %%
cv2.imshow("Added Image", final_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### Canny Edge Detection

# %%
import cv2

#Load the image
img= cv2.imread('images/lenna.png',0)

#apply canny edge detection
edges= cv2.Canny(img, 50,150) #adjust threshold if needed

#Display results
cv2.imshow('Original Image', img)
cv2.imshow('Canny Edge Detection', edges)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,3,1)
plt.title('Original Image')
plt.imshow(image, cmap='gray')
plt.subplot(1,3,2) ; plt.title('Sobel')
plt.imshow(binary_sobel, cmap='gray')
plt.subplot(1,3,3)
plt.title(' Canny')
plt.imshow(edges, cmap='gray')

# %%
img1=cv2.imread('images/circle.png',0)

# %%
sobelx= cv2.Sobel(img1, cv2.CV_64F,1,0,ksize=3) 
sobely= cv2.Sobel(img1, cv2.CV_64F,0,1,ksize=3)
combined_sobel= cv2.add(sobelx, sobely)
thresh, binary_sobel= cv2.threshold(combined_sobel, 50, 150,cv2.THRESH_BINARY)

#Apply Canny edge detection
edges= cv2.Canny(img1, 50,150)

plt.figure(figsize=(16,8))
plt.subplot(1,3,1)
plt.title('Original Image')
plt.imshow(img1, cmap='gray')
plt.subplot(1,3,2) ; plt.title('Sobel')
plt.imshow(binary_sobel, cmap='gray')
plt.subplot(1,3,3)
plt.title(' Canny')
plt.imshow(edges, cmap='gray')
