# %%
import cv2

#Load the image
image = cv2.imread("images/lenna.png")

cv2.imshow("Image", image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image.shape
# Out:
# (512, 512, 3)

# %%
# Extract the image dimensions
height, width, channels = image.shape

# Calculate the cropping dimensions
startRow = int(height * 0.15)
startCol = int(width * 0.15)
endRow = int(height * 0.85)
endCol = int(width * 0.85)
# Crop the image
cropped_image = image[startRow:endRow, startCol:endCol]

# Display the cropped image
cv2.imshow("Cropped Image", cropped_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
croppedImage = image[100:400, 50:400]
cv2.imshow("Cropped Image", cropped_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Load the image
image = cv2.imread("images/lenna.png")

cropped_image = image[100:250, 125:325]
cv2.imshow("Cropped Image", cropped_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cropped_image.shape
# Out:
# (150, 200, 3)

# %% [markdown]
# ### Cropping with PIL

# %%
from PIL import Image

# %%
image = Image.open("images/lenna.png")

# %%
image.crop((100,100,300,300))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>
